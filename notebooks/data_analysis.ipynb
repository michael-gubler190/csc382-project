# %% [markdown]
# Data Preprocessing

# %%
import pandas as pd

# Read the data
file_path = "../data/sp500_stocks.csv"
df = pd.read_csv(file_path)

df.head()
# Out:
#          date       open       high        low      close     volume symbol
# 0  2000-01-03  46.963910  47.075730  40.180235  42.938435  4674353.0      A
# 1  2000-01-04  40.627488  41.074766  38.614751  39.658394  4765083.0      A
# 2  2000-01-05  39.509317  39.658410  35.968390  37.198395  5758642.0      A
# 3  2000-01-06  36.751126  36.974765  34.663840  35.782028  2534434.0      A
# 4  2000-01-07  35.222915  39.322937  35.185644  38.763844  2819626.0      A
